# %% [markdown]
# # Convert the given Regular Expression to e-NFA

# %%
"""
Assumptions : 
only character string input should be given.
No space entered in the input

"""

# %%
regexp = "(a+b)*"
finite_automaton = evalRegex(constructTree(postfix(regexp)))
dot = generateTransitionTable(finite_automaton)
dot.write_png('automaton.png')

# %%
from IPython.display import Image
Image(filename='automaton.png')

# %%
# %pip install graphviz

# %%
pip install pydot
# Out:
# ...
#   Obtaining dependency information for pyparsing>=2.1.4 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/103.1 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/103.1 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/103.1 kB ? eta -:--:--
#    -------------------------------------  102.4/103.1 kB 535.8 kB/s eta 0:00:01
#    -------------------------------------- 103.1/103.1 kB 457.6 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
"""
Some Examples for regex : 
(a+b)*
ab*
a*b*
(a+b)*ab
a+abba
ab+aba
a+abbcc
(a+b)*b(a+b)
ab+bc+ca
lab+cab+dab
"""
